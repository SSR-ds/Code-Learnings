# %% [markdown]
# <a href="https://colab.research.google.com/github/SSR-ds/Code-Learnings/blob/master/Bank%20Deposits_Python%20Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.express as px
# %matplotlib inline

import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from datetime import datetime
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03dfb5ee-4f64-4567-9a2a-c0ab8c093779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03dfb5ee-4f64-4567-9a2a-c0ab8c093779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bank Deposits.csv to Bank Deposits (1).csv
# Saving CoppellRev9095.csv to CoppellRev9095 (1).csv
# Saving HillcrestRev8920.csv to HillcrestRev8920 (1).csv
# Saving HurstRev8572.csv to HurstRev8572 (1).csv
# Saving Mansfield_Ins_Rev0671.csv to Mansfield_Ins_Rev0671 (1).csv
# Saving Mansfield_Phys_Rev9456.csv to Mansfield_Phys_Rev9456 (1).csv
# Saving Physicians_Rev7973.csv to Physicians_Rev7973 (1).csv
# Saving Texoma_Rev1769.csv to Texoma_Rev1769 (1).csv
# Saving THPRev21393.csv to THPRev21393 (1).csv
# ...

# %%
bank_deposits = pd.read_csv('Bank Deposits.csv')

# %%
bank_deposits.shape
# Out:
# (4540, 8)

# %%
def replacecomma(row):
  try:
    return row.replace(',','')
  except AttributeError:
        return np.NaN

# %%
#bank_deposits['Amount']= bank_deposits['Amount'].apply(replacecomma)
#bank_deposits['Amount']=pd.to_numeric(bank_deposits['Amount'])

# %%
#bank_deposits['Posted Balance After Transaction']= bank_deposits['Posted Balance After Transaction'].apply(replacecomma)
#bank_deposits['Posted Balance After Transaction']=pd.to_numeric(bank_deposits['Posted Balance After Transaction'])

# %%
bank_deposits.dtypes
# Out:
# Provider Acct                        object
# Deposit Date                         object
# Description                          object
# Status                               object
# Amount                              float64
# Posted Balance After Transaction    float64
# Desc1                                object
# Desc2                                object
# dtype: object

# %%
df1 = pd.read_csv('CoppellRev9095.csv')
df2 = pd.read_csv('HillcrestRev8920.csv')
df3 = pd.read_csv('HurstRev8572.csv')
#df4 = pd.read_csv('Mansfield_Gov_Rev1945.csv')
df5 = pd.read_csv('Mansfield_Ins_Rev0671.csv')
df6 = pd.read_csv('Mansfield_Phys_Rev9456.csv')
df7 = pd.read_csv('Physicians_Rev7973.csv')
df8 = pd.read_csv('Texoma_Rev1769.csv')
df9 = pd.read_csv('THPRev21393.csv')
df10 = pd.read_csv('TMCCoppellMCRev29291.csv')
df11 = pd.read_csv('TMCHillcrestMCRev20168.csv')
df12 = pd.read_csv('TMCHurstMCRev20575.csv')
df13 = pd.read_csv('Uptown_Rev8807.csv')
df14 = pd.read_csv('ValleyRanchRev9419.csv')

# %%
df1['Amount']= df1['Amount'].apply(replacecomma)
df1['Amount']=pd.to_numeric(df1['Amount'])
df1['Posted Balance After Transaction']= df1['Posted Balance After Transaction'].apply(replacecomma)
df1['Posted Balance After Transaction']=pd.to_numeric(df1['Posted Balance After Transaction'])
df2['Amount']= df2['Amount'].apply(replacecomma)
df2['Amount']=pd.to_numeric(df2['Amount'])
df2['Posted Balance After Transaction']= df2['Posted Balance After Transaction'].apply(replacecomma)
df2['Posted Balance After Transaction']=pd.to_numeric(df2['Posted Balance After Transaction'])
df3['Amount']= df3['Amount'].apply(replacecomma)
df3['Amount']=pd.to_numeric(df3['Amount'])
df3['Posted Balance After Transaction']= df3['Posted Balance After Transaction'].apply(replacecomma)
df3['Posted Balance After Transaction']=pd.to_numeric(df3['Posted Balance After Transaction'])
#df4['Amount']= df4['Amount'].apply(replacecomma)
#df4['Amount']=pd.to_numeric(df4['Amount'])
#df4['Posted Balance After Transaction']= df4['Posted Balance After Transaction'].apply(replacecomma)
#df4['Posted Balance After Transaction']=pd.to_numeric(df4['Posted Balance After Transaction'])
df5['Amount']= df5['Amount'].apply(replacecomma)
df5['Amount']=pd.to_numeric(df5['Amount'])
df5['Posted Balance After Transaction']= df5['Posted Balance After Transaction'].apply(replacecomma)
df5['Posted Balance After Transaction']=pd.to_numeric(df5['Posted Balance After Transaction'])

# %%
df6['Amount']= df6['Amount'].apply(replacecomma)
df6['Amount']=pd.to_numeric(df6['Amount'])
df6['Posted Balance After Transaction']= df6['Posted Balance After Transaction'].apply(replacecomma)
df6['Posted Balance After Transaction']=pd.to_numeric(df6['Posted Balance After Transaction'])
df7['Amount']= df7['Amount'].apply(replacecomma)
df7['Amount']=pd.to_numeric(df7['Amount'])
df7['Posted Balance After Transaction']= df7['Posted Balance After Transaction'].apply(replacecomma)
df7['Posted Balance After Transaction']=pd.to_numeric(df7['Posted Balance After Transaction'])
df8['Amount']= df8['Amount'].apply(replacecomma)
df8['Amount']=pd.to_numeric(df8['Amount'])
df8['Posted Balance After Transaction']= df8['Posted Balance After Transaction'].apply(replacecomma)
df8['Posted Balance After Transaction']=pd.to_numeric(df8['Posted Balance After Transaction'])
df9['Amount']= df9['Amount'].apply(replacecomma)
df9['Amount']=pd.to_numeric(df9['Amount'])
df9['Posted Balance After Transaction']= df9['Posted Balance After Transaction'].apply(replacecomma)
df9['Posted Balance After Transaction']=pd.to_numeric(df9['Posted Balance After Transaction'])
df10['Amount']= df10['Amount'].apply(replacecomma)
df10['Amount']=pd.to_numeric(df10['Amount'])
df10['Posted Balance After Transaction']= df10['Posted Balance After Transaction'].apply(replacecomma)
df10['Posted Balance After Transaction']=pd.to_numeric(df10['Posted Balance After Transaction'])

# %%
df11['Amount']= df11['Amount'].apply(replacecomma)
df11['Amount']=pd.to_numeric(df11['Amount'])
df11['Posted Balance After Transaction']= df11['Posted Balance After Transaction'].apply(replacecomma)
df11['Posted Balance After Transaction']=pd.to_numeric(df11['Posted Balance After Transaction'])
df12['Amount']= df12['Amount'].apply(replacecomma)
df12['Amount']=pd.to_numeric(df12['Amount'])
df12['Posted Balance After Transaction']= df12['Posted Balance After Transaction'].apply(replacecomma)
df12['Posted Balance After Transaction']=pd.to_numeric(df12['Posted Balance After Transaction'])
df13['Amount']= df13['Amount'].apply(replacecomma)
df13['Amount']=pd.to_numeric(df13['Amount'])
df13['Posted Balance After Transaction']= df13['Posted Balance After Transaction'].apply(replacecomma)
df13['Posted Balance After Transaction']=pd.to_numeric(df13['Posted Balance After Transaction'])
df14['Amount']= df14['Amount'].apply(replacecomma)
df14['Amount']=pd.to_numeric(df14['Amount'])
df14['Posted Balance After Transaction']= df14['Posted Balance After Transaction'].apply(replacecomma)
df14['Posted Balance After Transaction']=pd.to_numeric(df14['Posted Balance After Transaction'])

# %%
df14.dtypes
# Out:
# Date                                 object
# Description                          object
# Status                               object
# Amount                              float64
# Posted Balance After Transaction    float64
# dtype: object

# %%
df14
# Out:
#           Date                                        Description  Status  \
# 0   10/29/2020  CREDIT FOR SALUCRO SV9T 8664307333 CO REF- SAL...  POSTED
# 1   10/29/2020  CREDIT FOR BCBS TEXAS HCCLAIMPMT CO REF- C2030...  POSTED
# 2   10/28/2020  CREDIT FOR SALUCRO SV9T     8664307333 CO REF-...  POSTED
# 3   10/28/2020  CREDIT FOR UNITEDHEALTHCARE HCCLAIMPMT CO REF-...  POSTED
# 4   10/28/2020  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# 5   10/27/2020  CREDIT FOR SALUCRO SV9T     8664307333 CO REF-...  POSTED
# 6   10/27/2020  CREDIT FOR MERCHANT SERVICE MERCH DEP CO REF- ...  POSTED
# 7   10/27/2020  CREDIT FOR UMR DALLAS COUNT HCCLAIMPMT CO REF-...  POSTED
# 8   10/27/2020  CREDIT FOR UMR CALUMET GP L HCCLAIMPMT CO REF-...  POSTED
# 9   10/27/2020  CREDIT FOR UNITEDHEALTHCARE HCCLAIMPMT CO REF-...  POSTED
# 10  10/26/2020  CREDIT FOR SALUCRO SV9T     8664307333 CO REF-...  POSTED
# 11  10/26/2020  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# ...

# %%
df1['Desc1'] =  df1['Description'].str[0:21]
df1['Desc2'] = df1['Description'].str[22:60]

df2['Desc1'] =  df2['Description'].str[0:21]
df2['Desc2'] = df2['Description'].str[22:60]

df3['Desc1'] =  df3['Description'].str[0:21]
df3['Desc2'] = df3['Description'].str[22:60]

#df4['Desc1'] =  df4['Description'].str[0:21]
#df4['Desc2'] = df4['Description'].str[22:60]

df5['Desc1'] =  df5['Description'].str[0:21]
df5['Desc2'] = df5['Description'].str[22:60]

df6['Desc1'] =  df6['Description'].str[0:21]
df6['Desc2'] = df6['Description'].str[22:60]

df7['Desc1'] =  df7['Description'].str[0:21]
df7['Desc2'] = df7['Description'].str[22:60]

df8['Desc1'] =  df8['Description'].str[0:21]
df8['Desc2'] = df8['Description'].str[22:60]

df9['Desc1'] =  df9['Description'].str[0:21]
df9['Desc2'] = df9['Description'].str[22:60]

df10['Desc1'] =  df10['Description'].str[0:21]
df10['Desc2'] = df10['Description'].str[22:60]

df11['Desc1'] =  df11['Description'].str[0:21]
df11['Desc2'] = df11['Description'].str[22:60]

df12['Desc1'] =  df12['Description'].str[0:21]
df12['Desc2'] = df12['Description'].str[22:60]

df13['Desc1'] =  df13['Description'].str[0:21]
df13['Desc2'] = df13['Description'].str[22:60]

df14['Desc1'] =  df14['Description'].str[0:21]
df14['Desc2'] = df14['Description'].str[22:60]

# %%
df1['Provider Acct'] = 'CoppellRev9095'
df2['Provider Acct'] = 'HillcrestRev8920'
df3['Provider Acct'] = 'HurstRev8572'
#df4['Provider Acct']='Mansfield_Gov_Rev1945'
df5['Provider Acct'] = 'Mansfield_Ins_Rev0671'
df6['Provider Acct'] = 'Mansfield_Phys_Rev9456'
df7['Provider Acct'] = 'Physicians_Rev7973'
df8['Provider Acct'] = 'Texoma_Rev1769'
df9['Provider Acct'] = 'THPRev21393'
df10['Provider Acct'] = 'TMCCoppellMCRev29291'
df11['Provider Acct'] = 'TMCHillcrestMCRev20168'
df12['Provider Acct'] = 'TMCHurstMCRev20575'
df13['Provider Acct'] = 'Uptown_Rev8807'
df14['Provider Acct'] = 'ValleyRanchRev9419'

# %%
df14.head()
# Out:
#          Date                                        Description  Status  \
# 0  10/29/2020  CREDIT FOR SALUCRO SV9T 8664307333 CO REF- SAL...  POSTED
# 1  10/29/2020  CREDIT FOR BCBS TEXAS HCCLAIMPMT CO REF- C2030...  POSTED
# 2  10/28/2020  CREDIT FOR SALUCRO SV9T     8664307333 CO REF-...  POSTED
# 3  10/28/2020  CREDIT FOR UNITEDHEALTHCARE HCCLAIMPMT CO REF-...  POSTED
# 4  10/28/2020  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
#
#     Amount  Posted Balance After Transaction                  Desc1  \
# 0   582.00                          25289.34  CREDIT FOR SALUCRO SV
# 1   583.50                          24707.34  CREDIT FOR BCBS TEXAS
# 2    96.80                          24123.84  CREDIT FOR SALUCRO SV
# 3   456.55                          24027.04  CREDIT FOR UNITEDHEAL
# 4  5310.20                          23570.49  CREDIT FOR BCBS TEXAS
#
#                                     Desc2       Provider Acct
# ...

# %%
values1 = df1[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values2 = df2[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values3 = df3[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
#values4 = df4[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values5 = df5[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values6 = df6[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values7 = df7[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values8 = df8[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values9 = df9[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values10 = df10[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values11 = df11[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values12 = df12[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values13 = df13[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]
values14 = df14[['Provider Acct','Date','Description','Status','Amount','Posted Balance After Transaction','Desc1','Desc2']]

# %%
values14.head()
# Out:
#         Provider Acct        Date  \
# 0  ValleyRanchRev9419  10/29/2020
# 1  ValleyRanchRev9419  10/29/2020
# 2  ValleyRanchRev9419  10/28/2020
# 3  ValleyRanchRev9419  10/28/2020
# 4  ValleyRanchRev9419  10/28/2020
#
#                                          Description  Status   Amount  \
# 0  CREDIT FOR SALUCRO SV9T 8664307333 CO REF- SAL...  POSTED   582.00
# 1  CREDIT FOR BCBS TEXAS HCCLAIMPMT CO REF- C2030...  POSTED   583.50
# 2  CREDIT FOR SALUCRO SV9T     8664307333 CO REF-...  POSTED    96.80
# 3  CREDIT FOR UNITEDHEALTHCARE HCCLAIMPMT CO REF-...  POSTED   456.55
# 4  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  5310.20
#
#    Posted Balance After Transaction                  Desc1  \
# 0                          25289.34  CREDIT FOR SALUCRO SV
# 1                          24707.34  CREDIT FOR BCBS TEXAS
# 2                          24123.84  CREDIT FOR SALUCRO SV
# 3                          24027.04  CREDIT FOR UNITEDHEAL
# ...

# %%
values1=values1.set_index('Provider Acct')
values2=values2.set_index('Provider Acct')
values3=values3.set_index('Provider Acct')
#values4=values4.set_index('Provider Acct')
values5=values5.set_index('Provider Acct')
values6=values6.set_index('Provider Acct')
values7=values7.set_index('Provider Acct')
values8=values8.set_index('Provider Acct')
values9=values9.set_index('Provider Acct')
values10=values10.set_index('Provider Acct')
values11=values11.set_index('Provider Acct')
values12=values12.set_index('Provider Acct')
values13=values13.set_index('Provider Acct')
values14=values14.set_index('Provider Acct')

# %%
values1.head()
# Out:
#                       Date                                        Description  \
# Provider Acct
# CoppellRev9095  10/29/2020  CREDIT FOR AETNA AS01 HCCLAIMPMT CO REF- 17902...
# CoppellRev9095  10/29/2020  CREDIT FOR AETNA AS01 HCCLAIMPMT CO REF- 17902...
# CoppellRev9095  10/29/2020  CREDIT FOR AETNA A04 HCCLAIMPMT CO REF- 179020...
# CoppellRev9095  10/28/2020  CREDIT FOR CIGNA HLTH LIFE  HCCLAIMPMT CO REF-...
# CoppellRev9095  10/28/2020  CREDIT FOR CIGNA EDGE TRANS HCCLAIMPMT CO REF-...
#
#                 Status   Amount  Posted Balance After Transaction  \
# Provider Acct
# CoppellRev9095  POSTED   418.96                          27276.99
# CoppellRev9095  POSTED  3795.30                          26858.03
# CoppellRev9095  POSTED  2694.10                          23062.73
# CoppellRev9095  POSTED  1308.23                          20368.63
# CoppellRev9095  POSTED  1290.56                          19060.40
#
# ...

# %%
total_dataframe = [values1,values2,values3,values5,values6,values7,values8,values9,values10,values11,values12,values13,values14]

# %%
result = pd.concat(total_dataframe)

# %%
result.rename({'Date': 'Deposit Date'}, axis=1, inplace=True)

# %%
result.head()
# Out:
#                Deposit Date  \
# Provider Acct
# CoppellRev9095   10/29/2020
# CoppellRev9095   10/29/2020
# CoppellRev9095   10/29/2020
# CoppellRev9095   10/28/2020
# CoppellRev9095   10/28/2020
#
#                                                       Description  Status  \
# Provider Acct
# CoppellRev9095  CREDIT FOR AETNA AS01 HCCLAIMPMT CO REF- 17902...  POSTED
# CoppellRev9095  CREDIT FOR AETNA AS01 HCCLAIMPMT CO REF- 17902...  POSTED
# CoppellRev9095  CREDIT FOR AETNA A04 HCCLAIMPMT CO REF- 179020...  POSTED
# CoppellRev9095  CREDIT FOR CIGNA HLTH LIFE  HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR CIGNA EDGE TRANS HCCLAIMPMT CO REF-...  POSTED
#
#                  Amount  Posted Balance After Transaction  \
# Provider Acct
# CoppellRev9095   418.96                          27276.99
# CoppellRev9095  3795.30                          26858.03
# CoppellRev9095  2694.10                          23062.73
# CoppellRev9095  1308.23                          20368.63
# ...

# %%
result.columns
# Out:
# Index(['Deposit Date', 'Description', 'Status', 'Amount',
#        'Posted Balance After Transaction', 'Desc1', 'Desc2'],
#       dtype='object')

# %%
result.shape
# Out:
# (237, 7)

# %%
result.dtypes
# Out:
# Deposit Date                         object
# Description                          object
# Status                               object
# Amount                              float64
# Posted Balance After Transaction    float64
# Desc1                                object
# Desc2                                object
# dtype: object

# %%
bank_deposits = bank_deposits.set_index('Provider Acct')

# %%
bank_deposits.head()
# Out:
#                Deposit Date  \
# Provider Acct
# CoppellRev9095     7/3/2020
# CoppellRev9095     7/6/2020
# CoppellRev9095     7/7/2020
# CoppellRev9095     7/8/2020
# CoppellRev9095     7/8/2020
#
#                                                       Description  Status  \
# Provider Acct
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR AETNA A04        HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
#
#                  Amount  Posted Balance After Transaction  \
# Provider Acct
# CoppellRev9095  3574.80                          12005.29
# CoppellRev9095   583.50                          12588.79
# CoppellRev9095  1298.73                          13887.52
# CoppellRev9095  1919.04                          22852.60
# ...

# %%
bank_deposits.columns
# Out:
# Index(['Deposit Date', 'Description', 'Status', 'Amount',
#        'Posted Balance After Transaction', 'Desc1', 'Desc2'],
#       dtype='object')

# %%
bank_deposits.shape
# Out:
# (4540, 7)

# %%
bank_deposits.dtypes
# Out:
# Deposit Date                         object
# Description                          object
# Status                               object
# Amount                              float64
# Posted Balance After Transaction    float64
# Desc1                                object
# Desc2                                object
# dtype: object

# %%
result1 = [bank_deposits,result]

# %%
new_dataframe = pd.concat(result1)

# %%
new_dataframe.shape
# Out:
# (4777, 7)

# %%
new_dataframe = new_dataframe.reset_index()

# %%
new_dataframe.head()
# Out:
#     Provider Acct Deposit Date  \
# 0  CoppellRev9095     7/3/2020
# 1  CoppellRev9095     7/6/2020
# 2  CoppellRev9095     7/7/2020
# 3  CoppellRev9095     7/8/2020
# 4  CoppellRev9095     7/8/2020
#
#                                          Description  Status   Amount  \
# 0  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  3574.80
# 1  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED   583.50
# 2  CREDIT FOR AETNA A04        HCCLAIMPMT CO REF-...  POSTED  1298.73
# 3  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  1919.04
# 4  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  7046.04
#
#    Posted Balance After Transaction                  Desc1  \
# 0                          12005.29  CREDIT FOR BCBS TEXAS
# 1                          12588.79  CREDIT FOR BCBS TEXAS
# 2                          13887.52   CREDIT FOR AETNA A04
# 3                          22852.60  CREDIT FOR BCBS TEXAS
# ...

# %%
new_dataframe2 = new_dataframe.reset_index().drop_duplicates(subset=['Deposit Date','Posted Balance After Transaction','Amount'],
                                       keep='first').set_index('Provider Acct')

# %%
new_dataframe2.shape
# Out:
# (4577, 8)

# %%
new_dataframe2.drop('index',axis=1,inplace=True)

# %%
new_dataframe2.head()
# Out:
#                Deposit Date  \
# Provider Acct
# CoppellRev9095     7/3/2020
# CoppellRev9095     7/6/2020
# CoppellRev9095     7/7/2020
# CoppellRev9095     7/8/2020
# CoppellRev9095     7/8/2020
#
#                                                       Description  Status  \
# Provider Acct
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR AETNA A04        HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
# CoppellRev9095  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED
#
#                  Amount  Posted Balance After Transaction  \
# Provider Acct
# CoppellRev9095  3574.80                          12005.29
# CoppellRev9095   583.50                          12588.79
# CoppellRev9095  1298.73                          13887.52
# CoppellRev9095  1919.04                          22852.60
# ...

# %%
new_dataframe3 = new_dataframe2.reset_index()

# %%
new_dataframe3.head()
# Out:
#     Provider Acct Deposit Date  \
# 0  CoppellRev9095     7/3/2020
# 1  CoppellRev9095     7/6/2020
# 2  CoppellRev9095     7/7/2020
# 3  CoppellRev9095     7/8/2020
# 4  CoppellRev9095     7/8/2020
#
#                                          Description  Status   Amount  \
# 0  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  3574.80
# 1  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED   583.50
# 2  CREDIT FOR AETNA A04        HCCLAIMPMT CO REF-...  POSTED  1298.73
# 3  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  1919.04
# 4  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  7046.04
#
#    Posted Balance After Transaction                  Desc1  \
# 0                          12005.29  CREDIT FOR BCBS TEXAS
# 1                          12588.79  CREDIT FOR BCBS TEXAS
# 2                          13887.52   CREDIT FOR AETNA A04
# 3                          22852.60  CREDIT FOR BCBS TEXAS
# ...

# %%
new_dataframe3['Deposit Date'] = pd.to_datetime(new_dataframe3['Deposit Date'])

# %%
#def replacecomma(row):
#  try:
#    return row.replace(',','')
#  except AttributeError:
#        return np.NaN

# %%
#new_dataframe3['Amount']= new_dataframe3['Amount'].apply(replacecomma)
#new_dataframe3['Amount']=pd.to_numeric(new_dataframe3['Amount'])

# %%
#new_dataframe3['Posted Balance After Transaction']= new_dataframe3['Posted Balance After Transaction'].apply(replacecomma)
#new_dataframe3['Posted Balance After Transaction']=pd.to_numeric(new_dataframe3['Posted Balance After Transaction'])

# %%
new_dataframe3.dtypes
# Out:
# Provider Acct                               object
# Deposit Date                        datetime64[ns]
# Description                                 object
# Status                                      object
# Amount                                     float64
# Posted Balance After Transaction           float64
# Desc1                                       object
# Desc2                                       object
# dtype: object

# %%
new_dataframe4 = new_dataframe3.groupby(new_dataframe3['Deposit Date'].dt.strftime('%B'))['Amount'].sum().sort_values()

# %%
new_dataframe4.sort_index()
# Out:
# Deposit Date
# August       3094110.63
# July         4175874.42
# June         2745228.99
# October      1663436.31
# September    3074320.50
# Name: Amount, dtype: float64

# %%
new_dataframe3['Deposit Month'] = new_dataframe3['Deposit Date'].dt.strftime('%b')

# %%
new_dataframe3.head()
# Out:
#     Provider Acct Deposit Date  \
# 0  CoppellRev9095   2020-07-03
# 1  CoppellRev9095   2020-07-06
# 2  CoppellRev9095   2020-07-07
# 3  CoppellRev9095   2020-07-08
# 4  CoppellRev9095   2020-07-08
#
#                                          Description  Status   Amount  \
# 0  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  3574.80
# 1  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED   583.50
# 2  CREDIT FOR AETNA A04        HCCLAIMPMT CO REF-...  POSTED  1298.73
# 3  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  1919.04
# 4  CREDIT FOR BCBS TEXAS       HCCLAIMPMT CO REF-...  POSTED  7046.04
#
#    Posted Balance After Transaction                  Desc1  \
# 0                          12005.29  CREDIT FOR BCBS TEXAS
# 1                          12588.79  CREDIT FOR BCBS TEXAS
# 2                          13887.52   CREDIT FOR AETNA A04
# 3                          22852.60  CREDIT FOR BCBS TEXAS
# ...

# %%
new_dataframe3.dtypes
# Out:
# Provider Acct                               object
# Deposit Date                        datetime64[ns]
# Description                                 object
# Status                                      object
# Amount                                     float64
# Posted Balance After Transaction           float64
# Desc1                                       object
# Desc2                                       object
# Deposit Month                               object
# dtype: object

# %%
new_dataframe3['Deposit Month'] = pd.Categorical(new_dataframe3['Deposit Month'], 
                      categories=["Jun","Jul","Aug","Sep","Oct"],
                      ordered=True)

# %%
new_dataframe3.dtypes
# Out:
# Provider Acct                               object
# Deposit Date                        datetime64[ns]
# Description                                 object
# Status                                      object
# Amount                                     float64
# Posted Balance After Transaction           float64
# Desc1                                       object
# Desc2                                       object
# Deposit Month                             category
# dtype: object

# %%
#from pandas.api.types import CategoricalDtype
#months_order = ['Jun','Jul','Aug','Sep','Oct']
#month_type = CategoricalDtype(categories=months_order, ordered=True)
#new_dataframe3['Deposit Month'] = new_dataframe3['Deposit Month'].astype(month_type)

# %%
final_pivot_df= new_dataframe3.pivot_table(index=['Provider Acct','Desc1'],columns=['Deposit Month'],values=['Amount'],aggfunc='sum',margins=True,margins_name='Total')

# %%
final_pivot_df.replace(np.nan, 0,inplace=True)

# %%
final_pivot_df
# Out:
#                                                          Amount              \
# Deposit Month                                               Jun         Jul
# Provider Acct          Desc1
# CoppellRev9095         BRANCH DEPOSIT                      0.00    14732.43
#                        CREDIT FOR AETNA A04             2655.67    21566.07
#                        CREDIT FOR AETNA A04                0.00        0.00
#                        CREDIT FOR AETNA AS01           40715.37    27800.89
#                        CREDIT FOR AETNA H09                0.00        0.00
#                        CREDIT FOR BCBS TEXAS           88041.43   238325.56
#                        CREDIT FOR BCBS TEXAS HCCLAI        0.00        0.00
#                        CREDIT FOR CIGNA                 7309.69    12923.05
#                        CREDIT FOR CIGNA                    0.00        0.00
#                        CREDIT FOR CIGNA EDGE             510.10     2578.15
# ...

# %%
final_pivot_df2= new_dataframe3.pivot_table(columns=['Provider Acct','Desc1'],index=['Deposit Month'],values=['Amount'],aggfunc='sum',margins=True,margins_name='Total')

# %%
final_pivot_df2.replace(np.nan, 0,inplace=True)

# %%
final_pivot_df2
# Out:
#                       Amount                                             \
# Provider Acct CoppellRev9095
# Desc1         BRANCH DEPOSIT CREDIT FOR AETNA A04 CREDIT FOR AETNA A04
# Deposit Month
# Jun                     0.00              2655.67                   0.0
# Jul                 14732.43             21566.07                   0.0
# Aug                 16471.85             16824.13                   0.0
# Sep                  4142.62              5683.83                   0.0
# Oct                     0.00               914.32                2694.1
# Total               35346.90             47644.02                2694.1
#
#                                                           \
# Provider Acct
# Desc1         CREDIT FOR AETNA AS01 CREDIT FOR AETNA H09
# Deposit Month
# Jun                        40715.37                 0.00
# Jul                        27800.89                 0.00
# Aug                        55528.68                 0.00
# ...

# %%
#!pip install pivottablejs


#from pivottablejs import pivot_ui
#from IPython.display import HTML
#pivot_ui(final_pivot_df2)

#pivot_ui(final_pivot_df,outfile_path='pivottablejs.html')
#HTML('pivottablejs.html')

# %%
from google.colab import files
new_dataframe2.to_csv('BankDeposits_new.csv') 
files.download('BankDeposits_new.csv')

# %%
#importing Pandas 
import pandas as pd
#importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
from IPython.display import HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !pip install pivottablejs

# %%
from pivottablejs import pivot_ui
from IPython.display import HTML

pivot_ui(new_dataframe3, outfile_path='pivottablejs.html')
HTML('pivottablejs.html')
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>PivotTable.js</title>
#
#         <!-- external libs from cdnjs -->
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-csv/0.71/jquery.csv-0.71.min.js"></script>
#
#
# ...
